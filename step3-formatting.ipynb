# %%
OPENAI_API_KEY = "OPENAI_API_KEY"

# %%
from enum import Enum

class Purpose(Enum):
    NOTE_LINEAR = "note-linear"
    NOTE_BULLET = "note-bullet"
    NOTE_BOTH = "note-both"
    QUESTIONSET_MCQ = "questionset-mcq"
    QUESTIONSET_WRITTEN = "questionset-written"
    QUESTIONSET_BOTH = "questionset-both"

# %%
from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

# %%
demo_dict = {
    "angel investors": "Angel investors are high-net-worth individuals who provide financial support to early-stage startups and entrepreneurs in exchange for ownership equity or convertible debt. They play a crucial role in the growth and development of startups, as they often invest in companies at a stage when traditional venture capital firms may not be willing to take the risk. These investors typically have a strong background in entrepreneurship or business, and they use their personal wealth, experience, and network to help startups succeed.Angel investors are considered the most critical component in creating a startup hub, as they provide the initial funding and support needed for startups to grow and attract further investment. They are often more willing to take risks on innovative ideas and unproven business models, which can lead to the creation of groundbreaking technologies and successful companies. In addition to financial support, angel investors often provide mentorship, strategic guidance, and access to their professional networks, which can be invaluable for early-stage startups.The investment process with angel investors is usually more informal and flexible compared to venture capital firms. They may invest individually or as part of an angel group or syndicate, pooling resources and expertise to support a startup. The amount of funding provided by angel investors can vary greatly, ranging from a few thousand dollars to several million, depending on the startup's needs and the investor's capacity.In summary, angel investors are essential players in the startup ecosystem, providing early-stage companies with the financial support, mentorship, and resources needed to grow and succeed. Their willingness to invest in high-risk ventures and contribute their expertise and networks make them a vital component in the creation and development of successful startup hubs.",
    "startup hub": "A startup hub is a centralized location or ecosystem where entrepreneurs, startups, investors, and other stakeholders come together to foster innovation, collaboration, and growth. These hubs provide a supportive environment for startups to develop and scale their businesses by offering resources such as mentorship, funding opportunities, networking events, and access to industry experts. They often feature co-working spaces, incubators, and accelerators, which help startups in various stages of development.In the context of the given document, a startup hub would be an ideal place for startups to connect with potential investors who can provide funding and support. The investors in these hubs are usually well-versed in the startup world and can make quick decisions on whether to invest in a particular startup or not. This is crucial for startups, as they thrive on speed and momentum.Furthermore, startup hubs often host events and workshops that help entrepreneurs refine their business ideas, develop their skills, and expand their networks. These hubs also facilitate collaboration between startups, allowing them to share knowledge, resources, and expertise, which can be invaluable in the early stages of a business.Overall, a startup hub is a dynamic and supportive ecosystem that plays a significant role in the success and growth of startups by providing them with the necessary resources, connections, and opportunities to thrive in the competitive business landscape.",
    "Silicon Valley": "Silicon Valley is a region in Northern California, specifically in the southern part of the San Francisco Bay Area, that serves as a global hub for technology, innovation, and entrepreneurship. The area is home to many of the world's largest and most successful technology companies, including Apple, Google, Facebook, and Tesla, as well as numerous startups and venture capital firms.The name \"Silicon Valley\" was coined in the 1970s due to the large number of silicon chip manufacturers and innovators in the region. The area has a rich history of technological advancements, dating back to the development of the semiconductor industry in the 1950s and 1960s. Since then, it has become synonymous with cutting-edge technology and innovation, attracting top talent and investment from around the world.Silicon Valley is known for its entrepreneurial culture, with a strong emphasis on collaboration, risk-taking, and rapid growth. The region's success can be attributed to several factors, including its proximity to top universities like Stanford and UC Berkeley, a highly skilled workforce, and a favorable business environment. Additionally, the presence of a large number of angel investors and venture capitalists in the area plays a crucial role in fueling the growth of startups and fostering innovation.The region's thriving ecosystem has led to the creation of numerous successful companies and has inspired other cities and countries to develop their own technology hubs. However, Silicon Valley also faces challenges, such as high living costs, income inequality, and concerns about the environmental impact of the tech industry. Despite these issues, Silicon Valley remains a global leader in technology and innovation, continuing to shape the future of various industries.",
    "venture capitalists": "Venture capitalists (VCs) are professional investors who specialize in providing capital to startups and early-stage companies in exchange for equity ownership or a stake in the business. They play a crucial role in the growth and development of innovative companies, often providing not only funding but also strategic guidance, mentorship, and access to networks.VCs typically invest in high-growth, high-risk ventures with the potential for significant returns on their investment. They are often part of larger venture capital firms, which pool funds from various sources such as wealthy individuals, pension funds, and institutional investors. These firms then allocate the funds to promising startups in their portfolio.When evaluating potential investments, VCs consider factors such as the strength of the founding team, the viability of the business model, the size of the market opportunity, and the potential for a successful exit through an acquisition or initial public offering (IPO). They often invest in multiple startups to diversify their portfolio and mitigate risk, as they expect that only a few of their investments will generate substantial returns, while others may fail or achieve only modest success.Venture capitalists typically invest in multiple funding rounds, starting with seed or early-stage financing and continuing through later-stage rounds as the company grows and requires additional capital. They may also participate in follow-on investments to maintain their ownership stake in the company.However, it is important to note that the interests of venture capitalists may not always align perfectly with those of the founders. VCs are focused on maximizing the overall return on their portfolio, which may lead them to push for aggressive growth strategies or prioritize certain startups over others. Additionally, their risk profiles may differ from those of the founders, as they are more likely to prefer high-risk, high-reward scenarios that can generate significant returns for their portfolio.In summary, venture capitalists are professional investors who provide crucial funding and support to startups and early-stage companies. They play a vital role in fostering innovation and driving economic growth, but their interests and risk profiles may not always align perfectly with those of the founders they invest in.",
    "Google": "Google is a multinational technology company that specializes in internet-related services and products. Founded in 1998 by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University, Google has grown to become one of the world's most valuable and influential companies. The company's primary offering is its search engine, which processes billions of search queries every day, helping users find relevant information on the internet.In addition to its search engine, Google offers a wide range of products and services, including online advertising technologies, cloud computing, software, and hardware. Some of its most popular products include the Android operating system, the Google Chrome web browser, Google Maps, and the Google Assistant, which is an AI-powered virtual assistant that can perform tasks and answer questions for users.Google is also known for its innovative work culture and commitment to research and development. The company invests heavily in cutting-edge technologies such as artificial intelligence, machine learning, and quantum computing. Google's research division, Google AI, focuses on advancing the field of AI and developing new applications for its technology.As part of its commitment to staying connected with the project mentioned in the document, Google may provide resources, expertise, and support to help the project succeed. This could include access to Google's vast array of tools and platforms, as well as collaboration with Google's team of engineers and researchers.In summary, Google is a global technology leader with a diverse range of products and services, a strong focus on innovation, and a commitment to supporting projects that align with its mission and values.",
    "momentum investors": "Momentum investors are a type of investors who focus on the recent performance and trends of stocks or other financial assets to make their investment decisions. They believe that assets that have performed well in the recent past are likely to continue doing so in the future, and vice versa for underperforming assets. This investment strategy is based on the idea that market trends and investor sentiment can drive asset prices beyond their fundamental values, creating opportunities for profit.Momentum investors typically use technical analysis to identify trends and patterns in asset prices, such as moving averages, relative strength, and trend lines. They may also consider factors like trading volume, market sentiment, and news events to gauge the strength of a trend and its potential to continue. By investing in assets with strong positive momentum, these investors aim to capitalize on the continuation of the trend and generate higher returns.However, momentum investing also comes with risks. Trends can reverse suddenly, leading to significant losses for investors who are late to exit their positions. Additionally, momentum investors may overlook the fundamental value of an asset, which could result in overvalued investments that eventually correct to their true value. To mitigate these risks, momentum investors often use stop-loss orders and other risk management techniques to protect their capital.In the context of startups and venture capital, momentum investors may focus on companies that are experiencing rapid growth, gaining market share, or attracting significant attention from the media and industry influencers. These investors may be more willing to take on higher risk in exchange for the potential of outsized returns if the startup continues its upward trajectory. However, as mentioned earlier, large-scale investors may have different risk profiles and motivations compared to founders, which could lead to conflicts of interest and differing opinions on the best course of action for the company.",
    "stock": "Stock refers to the ownership certificates of a particular company, representing a claim on part of the company's assets and earnings. It is a type of financial instrument that signifies an ownership interest in a corporation, entitling the stockholder to a proportion of the company's profits and assets. Stocks are also known as shares or equity.There are two main types of stock: common and preferred. Common stock usually entitles the owner to vote at shareholder meetings and to receive dividends, which are portions of the company's profits paid out to shareholders. Preferred stockholders generally do not have voting rights but have a higher claim on assets and earnings than common stockholders. This means that preferred stockholders receive dividends before common stockholders and have priority in case the company goes bankrupt and its assets are liquidated.Stocks can be bought and sold on stock exchanges, such as the New York Stock Exchange (NYSE) or the NASDAQ. The price of a stock is determined by supply and demand, influenced by factors such as the company's financial performance, market conditions, and investor sentiment.Investing in stocks can be a way to build wealth over time, as the value of the company may increase, leading to capital appreciation of the stock. Additionally, some stocks pay dividends, providing a source of income for investors. However, investing in stocks also comes with risks, as the value of a stock can decrease due to poor company performance or unfavorable market conditions.In the context of startups and venture capital, stocks play a crucial role in the relationship between founders and investors. When investors provide funding to a startup, they usually receive equity or stock in the company in exchange for their investment. This aligns the interests of both parties, as both founders and investors benefit from the growth and success of the company. However, as mentioned in the document, large-scale investors may have different motivations and risk profiles than founders, which can lead to conflicts in decision-making and strategy."
}

# %%
def formatting(purpose, keyword_description_dict):

    OPENAI_MODELS = ["gpt-4", "gpt-3.5-turbo"]
    llm = OpenAI(temperature=0, model_name=OPENAI_MODELS[0], openai_api_key=OPENAI_API_KEY)

    if purpose == Purpose.NOTE_LINEAR:
        PROMPT = """
            Referring to the following description: {description},
            write a note that explains the concept of: {key}.
            Explanations should be formatted in complete sentences.
        """
    
    elif purpose == Purpose.NOTE_BULLET:
        PROMPT = """
            Referring to the following description: {description},
            write a note that explains the concept of: {key}.
            Explanations should be formatted in bullet points.
        """
    
    elif purpose == Purpose.NOTE_BOTH:
        PROMPT = """
            Referring to the following description: {description},
            write a note that explains the concept of: {key}.
            Notes should involve both complete sentences and bullet points.
            You determine the suitable format for each content.
        """

    elif purpose == Purpose.QUESTIONSET_MCQ:
        PROMPT = """
            Referring to the following description: {description},
            write a set of mcq questions dealing with the concept of: {key}.
            Questions should be formatted in complete sentences.
            There should be five available choices for each question.
            You determine the suitable combination of basic and in-depth questions.
        """
    
    elif purpose == Purpose.QUESTIONSET_WRITTEN:
        PROMPT = """
            Referring to the following description: {description},
            write a set of written and open-ended questions dealing with the concept of: {key}.
            Questions should be formatted in complete sentences.
            You determine the suitable combination of basic and in-depth questions.
        """
    
    elif purpose == Purpose.QUESTIONSET_BOTH:
        PROMPT = """
            Referring to the following description: {description},
            write a set of (1) mcq questions and (2) written and open-ended questions
            dealing with the concept of: {key}.
            Questions should be formatted in complete sentences.
            If it's a mcq, there should be five available choices for each question.
            You determine the combination of mcq and written questions.
            You determine the suitable combination of basic and in-depth questions.
        """
    
    formatted_contents = {}
    
    for key in keyword_description_dict.keys():
        description = keyword_description_dict[key]

        # CHAIN1: Process query depending on the purpose
        CHAIN1_PROMPT = PromptTemplate(
            input_variables = ["description", "key"],
            template = PROMPT,
        )

        formatting_chain = LLMChain(llm=llm, prompt=CHAIN1_PROMPT)

        response = formatting_chain.run({"description": description, "key": key})

        # TODO: Further processings of response

        formatted_contents[key] = response
    
    return formatted_contents

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain.docstore.document import Document

def summary(keyword_description_dict):

    OPENAI_MODELS = ["gpt-4", "gpt-3.5-turbo"]
    llm = OpenAI(temperature=0, model_name=OPENAI_MODELS[0], openai_api_key=OPENAI_API_KEY)

    formatted_contents = {}

    for key in keyword_description_dict.keys():
        description = keyword_description_dict[key]

        summary_chain = load_summarize_chain(llm, chain_type="map_reduce")

        response = summary_chain.run([Document(page_content=description)])

        formatted_contents[key] = response
    
    return formatted_contents

# %% [markdown]
# ### Demos

# %%
import json

# %% [markdown]
# #### Notes in complete sentence

# %%
note_linear = formatting(Purpose.NOTE_LINEAR, demo_dict)
print(json.dumps(note_linear, indent=4))
# Out:
# {
#     "angel investors": "Angel investors are high-net-worth individuals who offer financial support to early-stage startups and entrepreneurs in exchange for ownership equity or convertible debt. They play a vital role in the growth and development of startups by investing in companies at a stage when traditional venture capital firms may not be willing to take the risk. These investors typically have a strong background in entrepreneurship or business and use their personal wealth, experience, and network to help startups succeed. They are considered a critical component in creating a startup hub, as they provide the initial funding, mentorship, strategic guidance, and access to their professional networks. The investment process with angel investors is usually more informal and flexible compared to venture capital firms, and they may invest individually or as part of a group. In essence, angel investors are essential players in the startup ecosystem, contributing to the creation and development of successful startup hubs.",
#     "startup hub": "A startup hub is a centralized ecosystem designed to support and foster the growth of startups and entrepreneurs by bringing together various stakeholders such as investors, industry experts, and other startups. This supportive environment offers resources such as mentorship, funding opportunities, networking events, and access to industry knowledge, which are crucial for the development and scaling of startup businesses. Startup hubs typically feature co-working spaces, incubators, and accelerators that cater to startups at different stages of growth. By facilitating collaboration, skill development, and connections to potential investors, startup hubs play a significant role in the success and growth of startups in the competitive business landscape.",
#     "Silicon Valley": "Silicon Valley is a region in Northern California, specifically in the southern part of the San Francisco Bay Area, that serves as a global hub for technology, innovation, and entrepreneurship. It is home to many of the world's largest and most successful technology companies, such as Apple, Google, Facebook, and Tesla, as well as numerous startups and venture capital firms. The name \"Silicon Valley\" was coined in the 1970s due to the large number of silicon chip manufacturers and innovators in the region. The area is known for its entrepreneurial culture, with a strong emphasis on collaboration, risk-taking, and rapid growth. Factors contributing to its success include proximity to top universities, a highly skilled workforce, and a favorable business environment, along with the presence of many angel investors and venture capitalists. Despite facing challenges like high living costs and income inequality, Silicon Valley remains a global leader in technology and innovation, shaping the future of various industries.",
#     "venture capitalists": "Venture capitalists (VCs) are professional investors who specialize in providing financial support to startups and early-stage companies in exchange for equity ownership or a stake in the business. They play a crucial role in fostering innovation and driving economic growth by investing in high-growth, high-risk ventures with the potential for significant returns. VCs are often part of larger venture capital firms that pool funds from various sources and allocate them to promising startups in their portfolio. In addition to funding, they also offer strategic guidance, mentorship, and access to networks. When evaluating potential investments, VCs consider factors such as the founding team, business model, market opportunity, and potential for a successful exit. They typically invest in multiple funding rounds and diversify their portfolio to mitigate risk. However, their interests and risk profiles may not always align perfectly with those of the founders they invest in, as they prioritize maximizing the overall return on their portfolio.",
#     "Google": "Google is a multinational technology company founded in 1998 by Larry Page and Sergey Brin, with its primary focus on providing internet-related services and products. The company's flagship offering is its search engine, which processes billions of queries daily, helping users find relevant information online. Google also offers a wide array of other products and services, such as online advertising technologies, cloud computing, software, and hardware, including popular products like the Android operating system, Google Chrome web browser, Google Maps, and the AI-powered Google Assistant. Known for its innovative work culture, Google heavily invests in cutting-edge technologies like artificial intelligence, machine learning, and quantum computing through its research division, Google AI. The company is committed to supporting projects that align with its mission and values by providing resources, expertise, and support.",
#     "momentum investors": "Momentum investors are a specific type of investors who base their investment decisions on the recent performance and trends of stocks or other financial assets. They believe that assets with a strong recent performance are likely to continue doing well in the future, and the opposite for underperforming assets. To identify these trends, momentum investors use technical analysis, considering factors like moving averages, relative strength, and trend lines, as well as trading volume, market sentiment, and news events. The goal of this investment strategy is to capitalize on the continuation of a trend and generate higher returns. However, this approach comes with risks, such as sudden trend reversals and overlooking the fundamental value of an asset. To mitigate these risks, momentum investors employ risk management techniques like stop-loss orders. In the context of startups and venture capital, momentum investors may focus on rapidly growing companies or those gaining significant attention, taking on higher risks for the potential of outsized returns.",
#     "stock": "Stock, also known as shares or equity, represents ownership certificates of a particular company, entitling the stockholder to a proportion of the company's profits and assets. There are two main types of stock: common and preferred. Common stockholders usually have voting rights at shareholder meetings and receive dividends, while preferred stockholders have a higher claim on assets and earnings but generally do not have voting rights. Stocks can be bought and sold on stock exchanges, with their prices determined by supply and demand. Investing in stocks can be a way to build wealth over time, but it also comes with risks due to fluctuations in the value of the stock. In the context of startups, stocks play a crucial role in the relationship between founders and investors, as investors often receive equity in the company in exchange for their investment."
# }

# %% [markdown]
# #### Notes in bullet points

# %%
note_bullet = formatting(Purpose.NOTE_BULLET, demo_dict)
for key in note_bullet.keys():
    print(key)
    print(note_bullet[key])
    print()
# Out:
# angel investors
# - Angel investors are high-net-worth individuals who invest in early-stage startups and entrepreneurs.
# - They provide financial support in exchange for ownership equity or convertible debt.
# - Angel investors play a crucial role in startup growth and development, often investing when traditional venture capital firms may not be willing to take the risk.
# - These investors typically have a strong background in entrepreneurship or business and use their personal wealth, experience, and network to help startups succeed.
# - Angel investors are considered essential in creating startup hubs, as they provide initial funding and support needed for startups to grow and attract further investment.
# - They are often more willing to take risks on innovative ideas and unproven business models, leading to the creation of groundbreaking technologies and successful companies.
# - In addition to financial support, angel investors provide mentorship, strategic guidance, and access to their professional networks.
# - The investment process with angel investors is usually more informal and flexible compared to venture capital firms.
# - Angel investors may invest individually or as part of an angel group or syndicate, pooling resources and expertise to support a startup.
# - The amount of funding provided by angel investors can vary greatly, ranging from a few thousand dollars to several million, depending on the startup's needs and the investor's capacity.
# - In summary, angel investors are essential players in the startup ecosystem, providing early-stage companies with the financial support, mentorship, and resources needed to grow and succeed.
#
# startup hub
# - A startup hub is a centralized location or ecosystem designed to support and foster the growth of startups and entrepreneurs.
# - Key components of a startup hub include:
#   - Co-working spaces for startups to work and collaborate
#   - Incubators and accelerators to help startups develop and scale their businesses
#   - Access to investors and funding opportunities
#   - Networking events and workshops to help entrepreneurs refine their ideas and expand their networks
#   - Collaboration opportunities between startups to share knowledge, resources, and expertise
# - Startup hubs play a significant role in the success and growth of startups by providing necessary resources, connections, and opportunities.
# - Investors in startup hubs are typically experienced in the startup world and can make quick decisions on investments.
# - Events and workshops hosted by startup hubs help entrepreneurs develop their skills and refine their business ideas.
# - Overall, a startup hub is a dynamic and supportive ecosystem that helps startups thrive in the competitive business landscape.
#
# Silicon Valley
# - Silicon Valley is a region in Northern California, specifically in the southern part of the San Francisco Bay Area.
# - Serves as a global hub for technology, innovation, and entrepreneurship.
# - Home to many of the world's largest and most successful technology companies, such as Apple, Google, Facebook, and Tesla.
# - Also home to numerous startups and venture capital firms.
# - Name "Silicon Valley" coined in the 1970s due to the large number of silicon chip manufacturers and innovators in the region.
# - Rich history of technological advancements, dating back to the development of the semiconductor industry in the 1950s and 1960s.
# - Synonymous with cutting-edge technology and innovation, attracting top talent and investment from around the world.
# - Known for its entrepreneurial culture, emphasizing collaboration, risk-taking, and rapid growth.
# - Success attributed to factors such as proximity to top universities, a highly skilled workforce, and a favorable business environment.
# - Presence of a large number of angel investors and venture capitalists in the area fuels growth of startups and fosters innovation.
# - Has inspired other cities and countries to develop their own technology hubs.
# - Faces challenges such as high living costs, income inequality, and environmental concerns related to the tech industry.
# - Remains a global leader in technology and innovation, shaping the future of various industries.
#
# venture capitalists
# - Venture capitalists (VCs) are professional investors who specialize in funding startups and early-stage companies.
# - They provide capital in exchange for equity ownership or a stake in the business.
# - VCs play a crucial role in the growth and development of innovative companies, often offering strategic guidance, mentorship, and access to networks.
# - They typically invest in high-growth, high-risk ventures with the potential for significant returns on their investment.
# - VCs are often part of larger venture capital firms, which pool funds from various sources such as wealthy individuals, pension funds, and institutional investors.
# - When evaluating potential investments, VCs consider factors such as the strength of the founding team, the viability of the business model, the size of the market opportunity, and the potential for a successful exit through an acquisition or initial public offering (IPO).
# - They often invest in multiple startups to diversify their portfolio and mitigate risk, as they expect that only a few of their investments will generate substantial returns, while others may fail or achieve only modest success.
# - Venture capitalists typically invest in multiple funding rounds, starting with seed or early-stage financing and continuing through later-stage rounds as the company grows and requires additional capital.
# - VCs may participate in follow-on investments to maintain their ownership stake in the company.
# - However, the interests of venture capitalists may not always align perfectly with those of the founders, as VCs are focused on maximizing the overall return on their portfolio and may prefer high-risk, high-reward scenarios.
#
# Google
# - Google is a multinational technology company founded in 1998 by Larry Page and Sergey Brin.
# - Specializes in internet-related services and products, including search engines, online advertising, cloud computing, software, and hardware.
# - Primary offering is its search engine, which processes billions of search queries daily, helping users find relevant information on the internet.
# - Offers a wide range of products and services, such as Android operating system, Google Chrome web browser, Google Maps, and Google Assistant (an AI-powered virtual assistant).
# - Known for its innovative work culture and commitment to research and development, particularly in areas like artificial intelligence, machine learning, and quantum computing.
# - Google AI, the company's research division, focuses on advancing the field of AI and developing new applications for its technology.
# - Provides resources, expertise, and support to projects that align with its mission and values, including access to tools, platforms, and collaboration with Google's team of engineers and researchers.
#
# momentum investors
# - Momentum investors are a type of investors who base their decisions on recent performance and trends of financial assets.
# - They believe that assets with strong recent performance are likely to continue doing well in the future, and vice versa for underperforming assets.
# - This investment strategy relies on the idea that market trends and investor sentiment can drive asset prices beyond their fundamental values, creating profit opportunities.
# - Momentum investors typically use technical analysis to identify trends and patterns in asset prices, such as moving averages, relative strength, and trend lines.
# - They may also consider factors like trading volume, market sentiment, and news events to gauge the strength of a trend and its potential to continue.
# - By investing in assets with strong positive momentum, these investors aim to capitalize on the continuation of the trend and generate higher returns.
# - However, momentum investing comes with risks, such as sudden trend reversals and overlooking the fundamental value of an asset, which could lead to overvalued investments.
# - To mitigate these risks, momentum investors often use stop-loss orders and other risk management techniques to protect their capital.
# - In the context of startups and venture capital, momentum investors may focus on companies experiencing rapid growth, gaining market share, or attracting significant attention from the media and industry influencers.
# - These investors may be more willing to take on higher risk in exchange for the potential of outsized returns if the startup continues its upward trajectory, but this could also lead to conflicts of interest and differing opinions on the best course of action for the company.
#
# stock
# - Stock represents ownership in a company, signifying a claim on part of the company's assets and earnings.
# - Also known as shares or equity, stocks are a type of financial instrument.
# - Two main types of stock: common and preferred.
#   - Common stock: usually grants voting rights and eligibility for dividends.
#   - Preferred stock: generally no voting rights, but higher claim on assets and earnings.
# - Stocks can be bought and sold on stock exchanges, such as NYSE or NASDAQ.
# - Stock prices are determined by supply and demand, influenced by factors like company performance, market conditions, and investor sentiment.
# - Investing in stocks can build wealth over time through capital appreciation and dividends, but also carries risks due to potential decreases in stock value.
# - In startups and venture capital, stocks play a crucial role in aligning the interests of founders and investors, who both benefit from the company's growth and success.

# %% [markdown]
# #### Notes in combined formatting

# %%
note_both = formatting(Purpose.NOTE_BOTH, demo_dict)
for key in note_both.keys():
    print(key)
    print(note_both[key])
    print()
# Out:
# c:\Users\offco\.conda\envs\langchain-tut\Lib\site-packages\langchain\llms\openai.py:169: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# c:\Users\offco\.conda\envs\langchain-tut\Lib\site-packages\langchain\llms\openai.py:696: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain.chat_models import ChatOpenAI`
#   warnings.warn(
# angel investors
# Angel Investors: A Brief Overview
#
# - Angel investors are high-net-worth individuals who invest in early-stage startups and entrepreneurs.
# - They provide financial support in exchange for ownership equity or convertible debt.
#
# Key Characteristics:
# - Strong background in entrepreneurship or business
# - Use personal wealth, experience, and network to support startups
# - Willing to take risks on innovative ideas and unproven business models
#
# Crucial Role in Startup Ecosystem:
# - Provide initial funding and support for startups to grow and attract further investment
# - Considered the most critical component in creating a startup hub
# - Offer mentorship, strategic guidance, and access to professional networks
#
# Investment Process:
# - More informal and flexible compared to venture capital firms
# - May invest individually or as part of an angel group or syndicate
# - Funding amounts can range from a few thousand dollars to several million
#
# In summary, angel investors play a vital role in the growth and development of early-stage startups by providing financial support, mentorship, and resources. Their willingness to invest in high-risk ventures and contribute their expertise and networks make them an essential component in the creation and development of successful startup hubs.
#
# startup hub
# A startup hub is a centralized ecosystem designed to support and foster the growth of startups and entrepreneurs. It brings together various stakeholders, including investors, industry experts, and other startups, to create a collaborative and innovative environment.
#
# Key features of a startup hub:
# - Centralized location for startups, entrepreneurs, investors, and other stakeholders
# - Offers resources such as mentorship, funding opportunities, networking events, and access to industry experts
# - Provides co-working spaces, incubators, and accelerators for startups in various stages of development
# - Facilitates collaboration and knowledge-sharing among startups
#
# Benefits of a startup hub:
# - Ideal place for startups to connect with potential investors who can provide funding and support
# - Investors in these hubs are well-versed in the startup world and can make quick investment decisions
# - Hosts events and workshops to help entrepreneurs refine their business ideas, develop skills, and expand networks
# - Encourages collaboration between startups, allowing them to share resources and expertise
#
# In conclusion, a startup hub is a dynamic and supportive ecosystem that plays a significant role in the success and growth of startups by providing them with the necessary resources, connections, and opportunities to thrive in the competitive business landscape.
#
# Silicon Valley
# Silicon Valley is a region in Northern California, specifically in the southern part of the San Francisco Bay Area, that serves as a global hub for technology, innovation, and entrepreneurship. It is home to many of the world's largest and most successful technology companies, as well as numerous startups and venture capital firms.
#
# Key Points:
# - Coined in the 1970s due to the large number of silicon chip manufacturers and innovators in the region
# - Rich history of technological advancements, dating back to the development of the semiconductor industry in the 1950s and 1960s
# - Synonymous with cutting-edge technology and innovation, attracting top talent and investment from around the world
# - Entrepreneurial culture with a strong emphasis on collaboration, risk-taking, and rapid growth
# - Proximity to top universities like Stanford and UC Berkeley, a highly skilled workforce, and a favorable business environment contribute to its success
# - Large number of angel investors and venture capitalists in the area fuel the growth of startups and foster innovation
# - Inspired other cities and countries to develop their own technology hubs
# - Faces challenges such as high living costs, income inequality, and concerns about the environmental impact of the tech industry
# - Remains a global leader in technology and innovation, continuing to shape the future of various industries
#
# venture capitalists
# Venture Capitalists: Key Concepts
#
# - Professional investors specializing in providing capital to startups and early-stage companies
# - Offer funding in exchange for equity ownership or a stake in the business
# - Play a crucial role in the growth and development of innovative companies
# - Provide strategic guidance, mentorship, and access to networks in addition to funding
#
# Key Characteristics:
# - Typically part of larger venture capital firms
# - Pool funds from various sources (wealthy individuals, pension funds, institutional investors)
# - Allocate funds to promising startups in their portfolio
# - Invest in multiple startups to diversify their portfolio and mitigate risk
#
# Investment Evaluation Factors:
# - Strength of the founding team
# - Viability of the business model
# - Size of the market opportunity
# - Potential for a successful exit (acquisition or IPO)
#
# Investment Stages:
# - Multiple funding rounds (seed, early-stage, later-stage)
# - Follow-on investments to maintain ownership stake
#
# Potential Misalignment of Interests:
# - VCs focus on maximizing overall return on their portfolio
# - May push for aggressive growth strategies or prioritize certain startups over others
# - Risk profiles may differ from those of the founders (VCs prefer high-risk, high-reward scenarios)
#
# In summary, venture capitalists are professional investors who provide crucial funding and support to startups and early-stage companies, fostering innovation and driving economic growth. However, their interests and risk profiles may not always align perfectly with those of the founders they invest in.
#
# Google
# Google: A Multinational Technology Company
#
# - Founded in 1998 by Larry Page and Sergey Brin
# - Specializes in internet-related services and products
# - One of the world's most valuable and influential companies
#
# Key Offerings:
# - Google Search Engine: Processes billions of search queries daily, helping users find relevant information on the internet
# - Online advertising technologies
# - Cloud computing
# - Software and hardware products
#
# Popular Products:
# - Android operating system
# - Google Chrome web browser
# - Google Maps
# - Google Assistant: AI-powered virtual assistant that performs tasks and answers questions for users
#
# Innovative Work Culture:
# - Strong commitment to research and development
# - Invests heavily in cutting-edge technologies such as artificial intelligence, machine learning, and quantum computing
# - Google AI: Research division focused on advancing the field of AI and developing new applications for its technology
#
# Support for Projects:
# - Google may provide resources, expertise, and support to help projects succeed
# - Access to Google's vast array of tools and platforms
# - Collaboration with Google's team of engineers and researchers
#
# In summary, Google is a global technology leader with a diverse range of products and services, a strong focus on innovation, and a commitment to supporting projects that align with its mission and values.
#
# momentum investors
# Title: Momentum Investors
#
# Momentum investors are a type of investors who base their investment decisions on the recent performance and trends of stocks or other financial assets. They believe that assets with strong positive momentum are likely to continue performing well in the future, and vice versa for underperforming assets. This investment strategy is driven by the idea that market trends and investor sentiment can push asset prices beyond their fundamental values, creating opportunities for profit.
#
# Key Characteristics of Momentum Investors:
# - Focus on recent performance and trends of financial assets
# - Use technical analysis to identify trends and patterns in asset prices
# - Consider factors like trading volume, market sentiment, and news events to gauge the strength of a trend
# - Aim to capitalize on the continuation of a trend and generate higher returns
# - May overlook the fundamental value of an asset, leading to potential risks
#
# Risks Associated with Momentum Investing:
# - Trends can reverse suddenly, leading to significant losses for investors who are late to exit their positions
# - Overvalued investments may eventually correct to their true value, resulting in losses
#
# Risk Management Techniques:
# - Use of stop-loss orders and other risk management techniques to protect capital
#
# Momentum Investors in the Context of Startups and Venture Capital:
# - Focus on companies experiencing rapid growth, gaining market share, or attracting significant attention from the media and industry influencers
# - May be more willing to take on higher risk in exchange for the potential of outsized returns if the startup continues its upward trajectory
# - Potential conflicts of interest and differing opinions on the best course of action for the company may arise due to different risk profiles and motivations between large-scale investors and founders
#
# stock
# Title: Understanding the Concept of Stock
#
# Introduction:
# - Stock represents ownership in a company
# - Provides stockholders with a claim on company's assets and earnings
# - Also known as shares or equity
# - Can be bought and sold on stock exchanges
#
# Types of Stock:
# - Common stock
#   - Entitles owner to vote at shareholder meetings
#   - Receives dividends (portions of company's profits)
# - Preferred stock
#   - No voting rights
#   - Higher claim on assets and earnings
#   - Receives dividends before common stockholders
#   - Priority in case of company bankruptcy
#
# Stock Price Determination:
# - Based on supply and demand
# - Influenced by factors such as:
#   - Company's financial performance
#   - Market conditions
#   - Investor sentiment
#
# Investing in Stocks:
# - Potential for wealth building through capital appreciation and dividends
# - Comes with risks due to possible decrease in stock value
#   - Poor company performance
#   - Unfavorable market conditions
#
# Stocks in Startups and Venture Capital:
# - Investors receive equity or stock in exchange for funding
# - Aligns interests of founders and investors
# - Potential conflicts due to differing motivations and risk profiles

# %% [markdown]
# #### MCQ Questionset

# %%
questionset_mcq = formatting(Purpose.QUESTIONSET_MCQ, demo_dict)
for key in questionset_mcq.keys():
    print(key)
    print(questionset_mcq[key])
    print()
# Out:
# angel investors
# 1) What is the primary role of angel investors in the startup ecosystem?
# a) Providing legal advice to startups
# b) Offering marketing services to startups
# c) Providing financial support and mentorship to early-stage startups
# d) Managing the day-to-day operations of startups
# e) Conducting market research for startups
#
# 2) Which of the following best describes the typical background of an angel investor?
# a) A recent college graduate with limited work experience
# b) A professional athlete with a large social media following
# c) A successful entrepreneur or business professional with personal wealth
# d) A government official with access to public funds
# e) A full-time venture capitalist with a large investment portfolio
#
# 3) In exchange for their investment, what do angel investors typically receive from startups?
# a) A fixed annual salary
# b) A percentage of the company's profits
# c) Ownership equity or convertible debt
# d) A seat on the company's board of directors
# e) Exclusive rights to the startup's products or services
#
# 4) How does the investment process with angel investors generally differ from that of venture capital firms?
# a) Angel investors require a more formal and structured investment process
# b) Angel investors only invest in companies with a proven track record of success
# c) Angel investors typically invest smaller amounts of money than venture capital firms
# d) The investment process with angel investors is usually more informal and flexible
# e) Angel investors focus solely on the financial aspects of a startup, while venture capital firms provide mentorship and guidance
#
# 5) Which of the following is NOT a typical benefit that angel investors provide to startups?
# a) Financial support
# b) Mentorship and strategic guidance
# c) Access to professional networks
# d) Assistance with product development
# e) Guaranteed success and profitability
#
# 6) What is a common characteristic of startups that angel investors are willing to invest in?
# a) They have a proven track record of profitability
# b) They have a large and established customer base
# c) They have a unique and innovative idea or business model
# d) They are part of a well-known and reputable industry
# e) They have a strong presence in the stock market
#
# 7) How do angel investors typically pool their resources and expertise to support a startup?
# a) By forming a venture capital firm
# b) By creating a nonprofit organization
# c) By establishing a government-funded program
# d) By joining an angel group or syndicate
# e) By partnering with a large corporation
#
# startup hub
# 1) What is the primary purpose of a startup hub?
# a) To provide a centralized location for entrepreneurs, startups, investors, and other stakeholders to foster innovation, collaboration, and growth.
# b) To offer a co-working space for freelancers and remote workers.
# c) To host networking events for professionals in various industries.
# d) To provide office space for established companies.
# e) To offer training courses for individuals looking to start a career in entrepreneurship.
#
# 2) Which of the following resources are commonly offered by startup hubs to support startups in their development?
# a) Mentorship, funding opportunities, networking events, and access to industry experts.
# b) Free office supplies, printing services, and discounted software.
# c) Legal advice, accounting services, and human resources support.
# d) Marketing and advertising services, public relations support, and branding assistance.
# e) Access to a gym, recreational facilities, and wellness programs.
#
# 3) What types of programs are typically featured in startup hubs to help startups in various stages of development?
# a) Co-working spaces, incubators, and accelerators.
# b) Online courses, webinars, and e-learning platforms.
# c) Job fairs, career counseling, and resume workshops.
# d) Trade shows, product demonstrations, and industry conferences.
# e) Networking events, panel discussions, and guest speaker presentations.
#
# 4) How do startup hubs facilitate collaboration between startups?
# a) By providing a shared workspace where startups can work side by side.
# b) By organizing team-building activities and social events.
# c) By offering a platform for startups to share knowledge, resources, and expertise.
# d) By connecting startups with potential partners and suppliers.
# e) By hosting competitions and challenges that encourage collaboration and innovation.
#
# 5) Why are investors in startup hubs considered crucial for the success of startups?
# a) They provide funding and support to help startups scale their businesses.
# b) They offer valuable advice and guidance on business strategy and operations.
# c) They have extensive networks and connections in the industry.
# d) They can make quick decisions on whether to invest in a particular startup or not.
# e) All of the above.
#
# Silicon Valley
# 1) What is Silicon Valley known for globally?
# a) Fashion industry
# b) Technology, innovation, and entrepreneurship
# c) Film production
# d) Agriculture
# e) Tourism
#
# 2) Where is Silicon Valley located?
# a) Southern California
# b) Northern California
# c) New York
# d) Texas
# e) Washington
#
# 3) Which of the following companies is NOT headquartered in Silicon Valley?
# a) Apple
# b) Google
# c) Facebook
# d) Tesla
# e) Coca-Cola
#
# 4) When was the name "Silicon Valley" coined?
# a) 1950s
# b) 1960s
# c) 1970s
# d) 1980s
# e) 1990s
#
# 5) What industry led to the development of Silicon Valley in the 1950s and 1960s?
# a) Automotive
# b) Aerospace
# c) Telecommunications
# d) Semiconductor
# e) Pharmaceutical
#
# 6) Which of the following factors contributes to Silicon Valley's success?
# a) Proximity to top universities
# b) A highly skilled workforce
# c) A favorable business environment
# d) Presence of angel investors and venture capitalists
# e) All of the above
#
# 7) What is a challenge faced by Silicon Valley?
# a) Low living costs
# b) Lack of skilled workforce
# c) High living costs
# d) Limited access to funding
# e) Poor infrastructure
#
# 8) Which university is located near Silicon Valley and plays a significant role in its success?
# a) Harvard University
# b) Yale University
# c) Stanford University
# d) Massachusetts Institute of Technology (MIT)
# e) University of Chicago
#
# 9) What is a key aspect of Silicon Valley's entrepreneurial culture?
# a) Risk aversion
# b) Slow growth
# c) Collaboration and risk-taking
# d) Focus on traditional industries
# e) Limited access to resources
#
# 10) Which of the following is NOT an impact of Silicon Valley's thriving ecosystem?
# a) Creation of successful companies
# b) Inspiration for other cities to develop technology hubs
# c) High income inequality
# d) Increased focus on environmental sustainability
# e) Attraction of top talent and investment from around the world
#
# venture capitalists
# 1) What is the primary role of venture capitalists in the growth and development of startups and early-stage companies?
# a) Providing office space and resources
# b) Offering legal advice and representation
# c) Providing capital in exchange for equity ownership or a stake in the business
# d) Assisting with marketing and public relations efforts
# e) Conducting market research and analysis
#
# 2) Which of the following is NOT a typical source of funds for venture capital firms?
# a) Wealthy individuals
# b) Pension funds
# c) Institutional investors
# d) Government grants
# e) Crowdfunding platforms
#
# 3) When evaluating potential investments, which factor is NOT commonly considered by venture capitalists?
# a) The strength of the founding team
# b) The viability of the business model
# c) The size of the market opportunity
# d) The potential for a successful exit through an acquisition or IPO
# e) The political affiliations of the founders
#
# 4) Why do venture capitalists often invest in multiple startups?
# a) To diversify their portfolio and mitigate risk
# b) To increase their chances of acquiring a majority stake in a successful company
# c) To create a competitive environment among startups
# d) To monopolize a specific industry or market
# e) To gain access to a wider range of business networks
#
# 5) In which funding round do venture capitalists typically begin investing in startups?
# a) Pre-seed financing
# b) Seed or early-stage financing
# c) Series A financing
# d) Series B financing
# e) Series C financing
#
# 6) How might the interests of venture capitalists differ from those of the founders they invest in?
# a) VCs may prioritize certain startups over others
# b) VCs may push for aggressive growth strategies
# c) VCs may prefer high-risk, high-reward scenarios
# d) VCs may focus on maximizing the overall return on their portfolio
# e) All of the above
#
# 7) What is the primary goal of venture capitalists when investing in startups and early-stage companies?
# a) To generate significant returns on their investment
# b) To create jobs and stimulate economic growth
# c) To foster innovation and technological advancements
# d) To gain control over the company's decision-making process
# e) To establish a long-term partnership with the founders
#
# Google
# 1) What is Google primarily known for?
# a) Its search engine
# b) Its social media platform
# c) Its online shopping website
# d) Its video streaming service
# e) Its email service
#
# 2) Who founded Google in 1998?
# a) Bill Gates and Paul Allen
# b) Steve Jobs and Steve Wozniak
# c) Larry Page and Sergey Brin
# d) Mark Zuckerberg and Eduardo Saverin
# e) Elon Musk and Peter Thiel
#
# 3) Where was Google founded by Larry Page and Sergey Brin?
# a) Harvard University
# b) Massachusetts Institute of Technology
# c) Stanford University
# d) University of California, Berkeley
# e) California Institute of Technology
#
# 4) Which of the following is NOT a product or service offered by Google?
# a) Android operating system
# b) Google Chrome web browser
# c) Google Maps
# d) Google Assistant
# e) Amazon Echo
#
# 5) What is the primary focus of Google's research division, Google AI?
# a) Developing new social media platforms
# b) Advancing the field of artificial intelligence
# c) Creating new hardware devices
# d) Improving internet connectivity worldwide
# e) Exploring space and extraterrestrial technology
#
# 6) How does Google support projects that align with its mission and values?
# a) By providing financial investments only
# b) By offering resources, expertise, and support
# c) By acquiring the projects and integrating them into Google's product lineup
# d) By promoting the projects on its search engine
# e) By sponsoring events and conferences related to the projects
#
# 7) Which of the following technologies does Google invest heavily in?
# a) Artificial intelligence
# b) Machine learning
# c) Quantum computing
# d) All of the above
# e) None of the above
#
# 8) What is the Google Assistant?
# a) A customer support representative
# b) A physical robot that assists with daily tasks
# c) An AI-powered virtual assistant
# d) A search engine feature that provides personalized recommendations
# e) A software development kit for creating applications
#
# 9) Which web browser is developed by Google?
# a) Firefox
# b) Safari
# c) Internet Explorer
# d) Opera
# e) Google Chrome
#
# 10) What is the primary purpose of Google's search engine?
# a) To display advertisements
# b) To collect user data for marketing purposes
# c) To help users find relevant information on the internet
# d) To compete with other search engines
# e) To promote Google's other products and services
#
# momentum investors
# 1) What is the primary focus of momentum investors when making investment decisions?
# a) The company's management team
# b) The asset's intrinsic value
# c) The recent performance and trends of financial assets
# d) The company's dividend history
# e) The overall market conditions
#
# 2) Which of the following tools do momentum investors typically use to identify trends and patterns in asset prices?
# a) Fundamental analysis
# b) Technical analysis
# c) Quantitative analysis
# d) Behavioral analysis
# e) Macroeconomic analysis
#
# 3) What is the main idea behind the momentum investing strategy?
# a) Market trends and investor sentiment can drive asset prices beyond their fundamental values
# b) Assets with low price-to-earnings ratios are undervalued and likely to appreciate
# c) Investors should hold a diversified portfolio to minimize risk
# d) Assets with high dividend yields provide stable income
# e) Investors should focus on long-term growth rather than short-term fluctuations
#
# 4) Which of the following factors might a momentum investor consider when gauging the strength of a trend?
# a) Trading volume
# b) Market sentiment
# c) News events
# d) All of the above
# e) None of the above
#
# 5) What is one of the main risks associated with momentum investing?
# a) Trends can reverse suddenly, leading to significant losses
# b) Momentum investing requires a large initial investment
# c) Momentum investing is only suitable for long-term investors
# d) Momentum investing is heavily regulated by financial authorities
# e) Momentum investing is not suitable for investing in stocks
#
# 6) In the context of startups and venture capital, what type of companies might momentum investors be interested in?
# a) Companies with a long history of stable dividends
# b) Companies with low debt levels
# c) Companies experiencing rapid growth or gaining market share
# d) Companies with a large market capitalization
# e) Companies with a strong focus on corporate social responsibility
#
# 7) To mitigate the risks associated with momentum investing, which risk management technique might momentum investors use?
# a) Diversification
# b) Dollar-cost averaging
# c) Stop-loss orders
# d) Value averaging
# e) Market timing
#
# 8) How might the motivations of large-scale investors differ from those of founders in the context of momentum investing?
# a) Large-scale investors may be more focused on short-term gains
# b) Large-scale investors may have a higher risk tolerance
# c) Large-scale investors may prioritize financial returns over the company's mission
# d) All of the above
# e) None of the above
#
# 9) What is the primary goal of momentum investors when investing in assets with strong positive momentum?
# a) To generate stable income through dividends
# b) To minimize risk through diversification
# c) To capitalize on the continuation of the trend and generate higher returns
# d) To invest in undervalued assets with strong growth potential
# e) To invest in companies with strong corporate governance
#
# 10) Which of the following is NOT a characteristic of momentum investing?
# a) Focusing on recent performance and trends of financial assets
# b) Using technical analysis to identify trends and patterns in asset prices
# c) Investing in assets with strong positive momentum
# d) Prioritizing the fundamental value of an asset over its recent performance
# e) Considering factors like trading volume and market sentiment to gauge the strength of a trend
#
# stock
# 1) What is the primary purpose of stocks in a company?
# a) To provide loans to the company
# b) To signify an ownership interest in the corporation
# c) To act as a form of currency for the company
# d) To serve as a company's marketing tool
# e) To represent the company's debt obligations
#
# 2) Which type of stock generally entitles the owner to vote at shareholder meetings and receive dividends?
# a) Preferred stock
# b) Common stock
# c) Convertible stock
# d) Callable stock
# e) Restricted stock
#
# 3) What is the main difference between common and preferred stockholders in terms of dividends and asset claims?
# a) Common stockholders have a higher claim on assets and dividends
# b) Preferred stockholders have a higher claim on assets and dividends
# c) Common stockholders receive dividends only in the form of additional shares
# d) Preferred stockholders receive dividends only in the form of additional shares
# e) There is no difference between common and preferred stockholders in these aspects
#
# 4) Which of the following factors can influence the price of a stock?
# a) The company's financial performance
# b) Market conditions
# c) Investor sentiment
# d) All of the above
# e) None of the above
#
# 5) In the context of startups and venture capital, why do investors usually receive equity or stock in the company in exchange for their investment?
# a) To ensure that the startup has enough cash to operate
# b) To align the interests of both founders and investors
# c) To provide a tax benefit for the investor
# d) To give the investor control over the company's operations
# e) To create a secondary market for the startup's stock
#
# 6) Which of the following is a potential risk associated with investing in stocks?
# a) The value of the stock can decrease due to poor company performance
# b) The stock may be difficult to sell in the future
# c) The company may not pay dividends regularly
# d) The investor may not have voting rights in the company
# e) All of the above
#
# 7) On which of the following stock exchanges can stocks be bought and sold?
# a) New York Stock Exchange (NYSE)
# b) NASDAQ
# c) London Stock Exchange (LSE)
# d) Tokyo Stock Exchange (TSE)
# e) All of the above
#
# 8) What is the primary benefit of investing in stocks that pay dividends?
# a) It provides a source of income for investors
# b) It guarantees a return on investment
# c) It increases the stock's market value
# d) It allows investors to vote at shareholder meetings
# e) It reduces the risk of the investment
#
# 9) In the case of a company going bankrupt and its assets being liquidated, which type of stockholders have priority?
# a) Common stockholders
# b) Preferred stockholders
# c) Both common and preferred stockholders have equal priority
# d) Neither common nor preferred stockholders have priority
# e) The priority depends on the specific company's policies
#
# 10) What is the main reason for conflicts in decision-making and strategy between founders and large-scale investors in a startup?
# a) Different levels of ownership in the company
# b) Different motivations and risk profiles
# c) Different levels of experience in the industry
# d) Different expectations for the company's growth
# e) Different preferences for dividend payouts

# %% [markdown]
# #### Written Questionset

# %%
questionset_written = formatting(Purpose.QUESTIONSET_WRITTEN, demo_dict)
for key in questionset_written.keys():
    print(key)
    print(questionset_written[key])
    print()
# Out:
# angel investors
# 1. What is the primary role of angel investors in the startup ecosystem?
#
# 2. How do angel investors differ from traditional venture capital firms in terms of their investment approach?
#
# 3. Can you provide an example of a successful startup that received initial funding from an angel investor?
#
# 4. What are some common characteristics of high-net-worth individuals who become angel investors?
#
# 5. How do angel investors typically decide which startups to invest in?
#
# 6. In what ways do angel investors provide mentorship and strategic guidance to the startups they invest in?
#
# 7. How does the investment process with angel investors differ from that of venture capital firms in terms of formality and flexibility?
#
# 8. Can you explain the concept of an angel group or syndicate and how it benefits both investors and startups?
#
# 9. What factors might influence the amount of funding an angel investor provides to a startup?
#
# 10. How do angel investors contribute to the creation and development of successful startup hubs?
#
# 11. What are some potential risks and challenges that angel investors face when investing in early-stage startups?
#
# 12. How do angel investors typically exit their investments and realize returns on their capital?
#
# 13. Can you discuss the importance of an angel investor's professional network in supporting the growth and success of a startup?
#
# 14. What are some strategies that startups can use to attract the attention of angel investors and secure funding?
#
# 15. How has the role of angel investors evolved over time, and what trends do you see shaping the future of angel investing?
#
# startup hub
# 1. What is the primary purpose of a startup hub in the context of supporting startups and entrepreneurs?
#
# 2. Can you provide examples of some well-known startup hubs around the world?
#
# 3. How do startup hubs foster innovation and collaboration among entrepreneurs and startups?
#
# 4. What types of resources and support do startup hubs typically offer to help startups develop and scale their businesses?
#
# 5. How do investors play a role in the startup hub ecosystem, and what benefits do they bring to startups?
#
# 6. In what ways do startup hubs facilitate networking and relationship-building among entrepreneurs, investors, and other stakeholders?
#
# 7. How do co-working spaces, incubators, and accelerators within startup hubs contribute to the growth and development of startups?
#
# 8. What types of events and workshops do startup hubs typically host to help entrepreneurs refine their business ideas and develop their skills?
#
# 9. How does collaboration between startups within a startup hub contribute to their overall success and growth?
#
# 10. What challenges might startups face when trying to become a part of a startup hub, and how can they overcome these challenges?
#
# 11. How can a startup determine if joining a startup hub is the right decision for their specific business needs and goals?
#
# 12. What are some key factors that contribute to the success of a startup hub in fostering a thriving ecosystem for startups and entrepreneurs?
#
# 13. How do startup hubs adapt to the changing needs and trends in the startup world to remain relevant and supportive?
#
# 14. Can you share any success stories of startups that have significantly benefited from being a part of a startup hub?
#
# 15. What advice would you give to an entrepreneur considering joining a startup hub to maximize their chances of success and growth?
#
# Silicon Valley
# 1. What is Silicon Valley and where is it located?
#
# 2. Why is Silicon Valley considered a global hub for technology, innovation, and entrepreneurship?
#
# 3. Can you name some of the largest and most successful technology companies based in Silicon Valley?
#
# 4. How did Silicon Valley get its name and when was it coined?
#
# 5. What is the historical significance of Silicon Valley in terms of technological advancements?
#
# 6. What are some key factors that have contributed to the success of Silicon Valley?
#
# 7. How do the top universities in the region, such as Stanford and UC Berkeley, play a role in Silicon Valley's success?
#
# 8. What is the importance of angel investors and venture capitalists in the growth of startups and innovation in Silicon Valley?
#
# 9. How has Silicon Valley's thriving ecosystem inspired other cities and countries to develop their own technology hubs?
#
# 10. What are some challenges faced by Silicon Valley, such as high living costs, income inequality, and environmental concerns?
#
# 11. In what ways does Silicon Valley continue to shape the future of various industries despite the challenges it faces?
#
# 12. How does the entrepreneurial culture in Silicon Valley encourage collaboration, risk-taking, and rapid growth?
#
# 13. Can you provide examples of successful companies that were founded in Silicon Valley and have had a significant impact on the global technology landscape?
#
# 14. What lessons can other regions learn from Silicon Valley in order to foster innovation and technological advancements in their own communities?
#
# 15. How do you think the future of Silicon Valley will evolve, considering the ongoing challenges and the ever-changing landscape of technology and innovation?
#
# venture capitalists
# 1. What is the primary role of venture capitalists in the growth and development of startups and early-stage companies?
#
# 2. How do venture capitalists typically source their funds for investment in startups?
#
# 3. What factors do venture capitalists consider when evaluating potential investments in startups?
#
# 4. Why do venture capitalists invest in multiple startups, and how does this strategy help mitigate risk?
#
# 5. Can you explain the different stages of funding rounds that venture capitalists may participate in as a startup grows?
#
# 6. How do venture capitalists provide strategic guidance, mentorship, and access to networks for the startups they invest in?
#
# 7. In what ways might the interests of venture capitalists and founders not perfectly align, and how can this impact the growth and direction of a startup?
#
# 8. How do venture capitalists balance their risk profiles with the potential for significant returns on their investments?
#
# 9. What are some examples of successful startups that have been backed by venture capital firms, and how did these firms contribute to their success?
#
# 10. How do venture capitalists typically exit their investments, and what factors influence their decision to exit through an acquisition or an initial public offering (IPO)?
#
# 11. What challenges do venture capitalists face in identifying and investing in promising startups, and how do they overcome these challenges?
#
# 12. How has the venture capital landscape evolved in recent years, and what trends do you foresee in the future of venture capital investing?
#
# 13. What advice would you give to a startup founder seeking venture capital funding for their business?
#
# 14. How do venture capital firms measure the success of their investments, and what key performance indicators (KPIs) do they typically track?
#
# 15. Can you discuss the importance of venture capital in fostering innovation and driving economic growth on a broader scale?
#
# Google
# 1. What is Google, and what are its primary areas of specialization?
#
# 2. Who founded Google, and in what year was it established?
#
# 3. Can you provide a brief overview of the history of Google, from its founding to its current status as a global technology leader?
#
# 4. What is Google's primary offering, and how does it help users find relevant information on the internet?
#
# 5. Besides its search engine, what are some other popular products and services offered by Google?
#
# 6. How does Google contribute to the fields of artificial intelligence, machine learning, and quantum computing?
#
# 7. What is the purpose of Google AI, and what are some of its key areas of focus?
#
# 8. How does Google's innovative work culture contribute to its success as a company?
#
# 9. In what ways does Google support projects that align with its mission and values?
#
# 10. Can you provide examples of how Google has collaborated with external projects or organizations to drive innovation and technological advancements?
#
# 11. How has Google's Android operating system impacted the global smartphone market?
#
# 12. What are some of the key features of the Google Assistant, and how does it utilize artificial intelligence to assist users?
#
# 13. How does Google's online advertising technology help businesses reach their target audiences?
#
# 14. What are some of the challenges Google faces in maintaining its position as a global technology leader, and how does the company address these challenges?
#
# 15. How does Google's commitment to research and development set it apart from other technology companies?
#
# momentum investors
# 1. What is the primary focus of momentum investors when making investment decisions?
#
# 2. How do momentum investors use the recent performance and trends of financial assets to predict future performance?
#
# 3. What is the underlying idea behind the momentum investing strategy?
#
# 4. Can you explain the role of technical analysis in momentum investing, and what are some common tools used by these investors?
#
# 5. How do momentum investors consider factors like trading volume, market sentiment, and news events in their investment decisions?
#
# 6. What are the potential benefits of momentum investing in terms of generating higher returns?
#
# 7. What are the main risks associated with momentum investing, and how can these risks be mitigated?
#
# 8. How do stop-loss orders and other risk management techniques help protect the capital of momentum investors?
#
# 9. In the context of startups and venture capital, what types of companies might attract the attention of momentum investors?
#
# 10. How might the risk profiles and motivations of large-scale investors differ from those of founders, and how could this lead to conflicts of interest in a startup's decision-making process?
#
# 11. Can you provide an example of a successful momentum investment and explain the factors that contributed to its success?
#
# 12. How does the momentum investing strategy differ from other investment strategies, such as value investing or growth investing?
#
# 13. What are some potential challenges or limitations of relying solely on momentum investing as an investment strategy?
#
# 14. How can an investor determine if momentum investing is a suitable strategy for their investment goals and risk tolerance?
#
# 15. Are there any specific market conditions or environments in which momentum investing tends to perform better or worse?
#
# stock
# 1. What is the definition of stock in the context of a company's ownership?
#
# 2. How do stocks represent a claim on a company's assets and earnings?
#
# 3. What are the two main types of stock, and how do they differ in terms of shareholder rights and privileges?
#
# 4. Can you explain the concept of dividends and how they relate to stocks?
#
# 5. How are stock prices determined, and what factors can influence their value?
#
# 6. What are some potential benefits of investing in stocks, and what risks should investors be aware of?
#
# 7. How do stocks play a role in the relationship between startup founders and investors?
#
# 8. In what ways can the motivations and risk profiles of large-scale investors differ from those of founders, and how might this affect decision-making and strategy within a company?
#
# 9. Can you provide an example of a situation where investing in stocks led to significant financial gains for an investor?
#
# 10. What are some strategies that investors can use to minimize the risks associated with investing in stocks?
#
# 11. How do stock exchanges, such as the New York Stock Exchange (NYSE) or the NASDAQ, facilitate the buying and selling of stocks?
#
# 12. What is the importance of shareholder voting rights, and how do they impact the management and direction of a company?
#
# 13. Can you explain the concept of capital appreciation and how it relates to investing in stocks?
#
# 14. How do companies decide on the amount and frequency of dividend payments to their shareholders?
#
# 15. What are some key indicators that investors should consider when evaluating the potential value and performance of a stock?

# %% [markdown]
# #### Mixed Questionset

# %%
questionset_both = formatting(Purpose.QUESTIONSET_BOTH, demo_dict)
for key in questionset_both.keys():
    print(key)
    print(questionset_both[key])
    print()

# %% [markdown]
# #### Summary

# %%
summary_demo = summary(demo_dict)
for key in summary_demo.keys():
    print(key)
    print(summary_demo[key])
    print()
# Out:
# angel investors
# Angel investors are wealthy individuals who provide early-stage startups with financial support, mentorship, and professional network access in exchange for equity or convertible debt. They play a vital role in startup growth and success, often investing in high-risk ventures and contributing to the development of startup hubs.
#
# startup hub
# A startup hub is a central ecosystem that supports entrepreneurs, startups, and investors by providing resources, networking, mentorship, and growth opportunities in a collaborative environment.
#
# Silicon Valley
# Silicon Valley, in Northern California, is a leading global technology and innovation hub, hosting major tech companies and benefiting from top universities, a skilled workforce, and a favorable business environment.
#
# venture capitalists
# Venture capitalists (VCs) are professional investors who support startups and early-stage companies with capital and resources in exchange for equity. They contribute to innovation and economic growth by investing in high-risk, high-growth ventures. VCs are part of larger firms that diversify their investments to mitigate risk, considering factors such as the founding team, business model, and market opportunity. However, their interests and risk profiles may not always align with those of the founders.
#
# Google
# Google, founded in 1998, is a multinational tech company offering internet-related services and products, including its search engine, online advertising, cloud computing, software, and hardware. Known for its innovative work culture, Google focuses on research and development in artificial intelligence, machine learning, and quantum computing through its Google AI division.
#
# momentum investors
# Momentum investors make decisions based on recent performance and trends, using various tools to identify strong assets. They face risks like trend reversals and may overlook fundamentals. To manage risks, they use stop-loss orders and focus on fast-growing startups, but may face conflicts with founders due to differing motivations.
#
# stock
# Stocks, representing company ownership, come in two main types: common stock with voting rights and dividends, and preferred stock with prioritized dividends and asset claims but no voting rights. Stocks are traded on exchanges, and their prices depend on supply and demand. While investing in stocks can build wealth, it also carries risks, and in startups, stocks help align founders' and investors' interests, though conflicts may still occur.
